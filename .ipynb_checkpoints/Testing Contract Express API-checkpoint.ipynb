# %% [markdown]
# Install required packages

# %% [markdown]
# How to do:
# * Get a valid access token using Postman
# * Create an initial request to the API to make sure everything works correctly
# * _Export_ datasheet to get all Contract IDs
# * Open the CSV file in Python and extract all contract IDs
# * Create a list with all Contract IDs
#     + Make a GET request to "/api/contracts/{ContractID}/documents" to update documents
#     + Make a GET request to "/api/contracts/{ContractID}/documents/zip" to download all documents
#     + Use the following code to save to file:<br>
#     `with open("response.zip", 'wb') as fd:
#     for chunk in response.iter_content(chunk_size=128):
#         fd.write(chunk)`
#     * Potentially: Use Python to extract all .docx files <a href="https://stackoverflow.com/questions/3451111/unzipping-files-in-python">see here</a>

# %%
# !pip3 install requests
# Out:
# Requirement already satisfied: requests in c:\users\constantinos\anaconda3\lib\site-packages

# %%
#housekeeping
import requests
import pprint
import zipfile

# %%
headers = {
        "Host": "myapp.com", 
        "Authorization" : "",
        "Cache-Control" : "no-cache",
        "Postman-Token" : ""
          }

response = requests.get("https://myapp.com/app/api/templates", headers=headers)
print(response)

pp = pprint.PrettyPrinter(indent=4)
pp.pprint(response.text)
# Out:
# <Response [200]>
# ('[{"Reference":"Non Disclosure '
#  'Agreement","Version":"2.0","FolderId":17883,"DatasheetId":null,"ProfileReference":null,"Name":"Non '
#  'Disclosure '
#  'Agreement","Description":"","Keywords":"","UploadedBy":"system","UploadedById":"system","UploadedOn":"2017-09-02T11:13:46.637","IsInactive":false,"Advertise":false,"Imported":false,"ImportMajor":false,"ImportAutomatic":false,"ImportAvailable":false,"ESignatureEnabled":true,"ESignatureGuestEnabled":true,"Share":1,"EffectiveRight":3,"SLAMetricsEnabled":true,"UseNegotiations":true,"UseComments":true,"DocumentUploadEnabled":true,"TemplateVersions":[],"Links":[]}]')

# %%
prefix = "https://myapp.com/app"
API_call = "/api/contracts/603137/documents/zip"
url = prefix + API_call
response = requests.get(url, headers = headers)
print(response)
print(response.content)
# Out:
# <Response [200]>
# b'PK\x03\x04\x14\x00\x00\x00\x08\x00\xf2t"K\xe5\xad\x9b\xf3\xbf{\x00\x00\x98\x9a\x00\x00\x12\x00\x00\x00NDA for asdfa.docx\xec\xbcUp%A\x96,x\xc5\xcc\xcc\x8c%fff\xa6\x12\xb3Tbffff\x96JR\x89\x19J\xcc\xcc\xcc\xcc%\xc6\xbb\xd5=ol\xbbggw\xed}\xed\xc7\xce1\xcb\xccH\xbbv?"\xfd\xb8{\xc4\x89\xccP\x92\x05\x03G\x07@\x02\xa0\x01\xce.\xa4\xb2\xadF\xf2\xe3\xed \x00@0\x1c\x00\x80\x06\x80\x06\xfd.jo\xe7bf\xe7b\xa0\xe6\xe9`\xe6\xac\xc7\xe0akC\\\x04\x0eJ]\x00\x00\x05\xfcO\xfc\xff:\xa6\xd2&\x14\x06\x98\x90\xc5\xfd)\xc61\xd9\xed<\xd1C\xd6\x1b\x00-J
f1\xcft\xfd\xd7D\xbd\xd2\xdbR!kO\xf2\xc3\x08\xb5G\x14\xf3\xf8\xbdjh\xf9\xf4\x1b\xc6$[\xff\xa6\xf0\x0c\xb1\xa0\xf8\xd7\x11\xed\x9a\x86\xaazUj\xd5\xa5y\xed1;\x87\xf1\xb3\xf4\x93\xf1\x8e\x99\xbe\xa1\x81\x11\xabj\x95\xa0\t\x1e\x9e\x1c#\xeb\x80\x98\x1c\xe0\x91\xacT%\xd3\xc0/3\xa9\n\xf8\xdc\x0b<\xb9\x01\xbe\xa0@\xda\xd06%\xd2\xf2\xfc$\xb8d\xb7\x96\x13\xcb\xfbc\xc6&\x ...

# %%
response.raw

# %%
response.raw.read(15)
# Out:
# b''

# %%
with open("response.zip", 'wb') as fd:
    for chunk in response.iter_content(chunk_size=128):
        fd.write(chunk)

# %% [markdown]
# ## Now try to do it properly

# %%
headers = {
        "Host": "myapp.com", 
        "Authorization" : "",
        "Cache-Control" : "no-cache",
        "Postman-Token" : ""
          }

response = requests.get("https://myapp.com/app/api/templates", headers=headers)
print(response)

pp = pprint.PrettyPrinter(indent=4)
pp.pprint(response.text)
# Out:
# <Response [200]>
# ('[{"Reference":"Non Disclosure '
#  'Agreement","Version":"2.0","FolderId":17883,"DatasheetId":null,"ProfileReference":null,"Name":"Non '
#  'Disclosure '
#  'Agreement","Description":"","Keywords":"","UploadedBy":"system","UploadedById":"system","UploadedOn":"2017-09-02T11:13:46.637","IsInactive":false,"Advertise":false,"Imported":false,"ImportMajor":false,"ImportAutomatic":false,"ImportAvailable":false,"ESignatureEnabled":true,"ESignatureGuestEnabled":true,"Share":1,"EffectiveRight":3,"SLAMetricsEnabled":true,"UseNegotiations":true,"UseComments":true,"DocumentUploadEnabled":true,"TemplateVersions":[],"Links":[]}]')

# %%
files = "603142,603137,603136,603134,603133".split(",")

# %%
for file in files:
    prefix = "https://myapp.com/app"
    API_call = "/api/contracts/{}/documents/zip".format(file)
    url = prefix + API_call
    response = requests.get(url, headers = headers)
    print(response)
    print("File ID:", str(file) , " " ,response.content[15])
# Out:
# <Response [401]>
# File ID: 603142   117
# <Response [401]>
# File ID: 603137   117
# <Response [401]>
# File ID: 603136   117
# <Response [401]>
# File ID: 603134   117
# <Response [401]>
# File ID: 603133   117

# %%
prefix = "https://myapp.com/app"
API_call = "/api/contracts/603136/documents"#.format(file)
url = prefix + API_call
response = requests.get(url, headers = headers)
print(response)
print(response.content)
# Out:
# <Response [401]>
# b'{"Message":"Unauthorized"}'

# %%
prefix = "https://myapp.com/app"
API_call = "/api/contracts/603136/documents/zip"#.format(file)
url = prefix + API_call
response = requests.get(url, headers = headers)
print(response)
print(response.content)
# Out:
# <Response [401]>
# b'{"Message":"Unauthorized"}'

# %%
with zipfile.ZipFile("response.zip","r") as zip_ref:
    zip_ref.extractall("")
